# %%
import os,sys
import pandas as pd
import numpy as np

# %% [markdown]
# # Functions

# %%
# HP SELECTION - INNER LOOP
# find out the best HP per fold
def selectHP(metric, perf_inner):
    data1 = []
    data2 = []
    data3 = []
    for target in perf_inner['target'].unique():
        # extract results for the current target
        sub = perf_inner.loc[perf_inner['target']==target]
    
        # get AUC performance averaged for each given fold i.e. averaged over the two inner folds
        subgrouped3 = sub.groupby(['ofold', 'hp']).mean().reset_index().sort_values('auc', ascending=False)    
        
        
        # extract best AUC for each of the three folds
        sub1 = subgrouped3.loc[subgrouped3['ofold']==1].sort_values(metric, ascending=False).drop(['ofold','ifold','auc','recall','precision','kappa'],axis=1).head(1)
        sub2 = subgrouped3.loc[subgrouped3['ofold']==2].sort_values(metric, ascending=False).drop(['ofold','ifold','auc','recall','precision','kappa'],axis=1).head(1)
        sub3 = subgrouped3.loc[subgrouped3['ofold']==3].sort_values(metric, ascending=False).drop(['ofold','ifold','auc','recall','precision','kappa'],axis=1).head(1)

        data1.append(sub1.values[0])
        data2.append(sub2.values[0])
        data3.append(sub3.values[0])
        
    hp_fold1 = pd.DataFrame(data1, columns=[ 'hp_fold1','target'])
    hp_fold2 = pd.DataFrame(data2, columns=[ 'hp_fold2','target'])
    hp_fold3 = pd.DataFrame(data3, columns=[ 'hp_fold3','target'])
    
    return hp_fold1.merge(hp_fold2, on='target').merge(hp_fold3, on='target')

# %%
# Find out the performance - OUTER LOOP
# using the HP selected in inner loop
def getOuterLoopPerformance(perf_outer, hp_select):    
    
    data1,data2,data3=[],[],[]
    for i in range(526):
        
        hp_fold1 = hp_selection.loc[hp_selection['target']==i]['hp_fold1'].values[0]
        hp_fold2 = hp_selection.loc[hp_selection['target']==i]['hp_fold2'].values[0]
        hp_fold3 = hp_selection.loc[hp_selection['target']==i]['hp_fold3'].values[0]
        
        perf_fold1 = perf_outer.loc[(perf_outer['target']==i)&(perf_outer['hp']==hp_fold1)&(perf_outer['ofold']==1)]
        perf_fold2 = perf_outer.loc[(perf_outer['target']==i)&(perf_outer['hp']==hp_fold2)&(perf_outer['ofold']==2)]
        perf_fold3 = perf_outer.loc[(perf_outer['target']==i)&(perf_outer['hp']==hp_fold3)&(perf_outer['ofold']==3)]

        ####  one target missing for SVM and RF
        if perf_fold1.shape[0]==0 or perf_fold2.shape[0]==0 or perf_fold3.shape[0]==0:continue
        ####
                
        data1.append(perf_fold1.values[0])
        data2.append(perf_fold2.values[0])
        data3.append(perf_fold3.values[0])
        
        
    all_perf_fold1 = pd.DataFrame(data1, columns=perf_fold1.columns.values)
    all_perf_fold2 = pd.DataFrame(data2, columns=perf_fold2.columns.values)
    all_perf_fold3 = pd.DataFrame(data3, columns=perf_fold3.columns.values)
    
    return all_perf_fold1,all_perf_fold2,all_perf_fold3

# %% [markdown]
# # XGboost

# %% [markdown]
# ## Inner fold - HP search

# %%
xgboost_df = pd.read_csv('results_v5_xgboost_ecfp/all-nested-cv-perf-scores.csv', header=0, sep="\t")

# separate inner and out loop results
xgb_inner = xgboost_df.loc[xgboost_df['ifold'].isin([1,2])].copy(deep=True).drop(['al','sample'],axis=1)
xgb_outer = xgboost_df.loc[xgboost_df['ifold'].isin([0])].copy(deep=True).drop(['al','sample'],axis=1)
del xgboost_df

# %%
xgb_inner.head()
# Out:
#       ofold  ifold  target                                                 hp  \
# 9468      1      1       0  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 9469      1      1       0  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 9470      1      1       0  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 9471      1      1       0  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 9472      1      1       0  booster_gbtree-learning_rate_0.05-max_depth_5-...
#
#            auc    recall  precision     kappa
# 9468  0.808374  0.702326   0.731826  0.507079
# 9469  0.804593  0.857364   0.603053  0.404244
# 9470  0.792723  0.913178   0.523556  0.253211
# 9471  0.810966  0.699225   0.722756  0.495144
# 9472  0.810930  0.865116   0.605863  0.412486

# %%
# select best HP per fold
hp_selection = selectHP('auc', xgb_inner)

# %%
hp_selection.head()
# Out:
#                                             hp_fold1  target  \
# 0  booster_gbtree-learning_rate_0.05-max_depth_10...     0.0
# 1  booster_gbtree-learning_rate_0.05-max_depth_5-...   100.0
# 2  booster_gbtree-learning_rate_0.05-max_depth_5-...   101.0
# 3  booster_gbtree-learning_rate_0.05-max_depth_5-...   102.0
# 4  booster_gbtree-learning_rate_0.05-max_depth_10...   103.0
#
#                                             hp_fold2  \
# 0  booster_gbtree-learning_rate_0.05-max_depth_10...
# 1  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 2  booster_gbtree-learning_rate_0.05-max_depth_10...
# 3  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 4  booster_gbtree-learning_rate_0.05-max_depth_5-...
#
#                                             hp_fold3
# 0  booster_gbtree-learning_rate_0.05-max_depth_10...
# 1  booster_gbtree-learning_rate_0.05-max_depth_10...
# 2  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 3  booster_gbtree-learning_rate_0.05-max_depth_5-...
# 4  booster_gbtree-learning_rate_0.05-max_depth_10...

# %% [markdown]
# ## Outer folds - Models evaluations

# %%
# use the selected HP to find out the performance in outer loop
perf_fold1, perf_fold2, perf_fold3 = getOuterLoopPerformance(xgb_outer, hp_selection)
perf_fold1.to_csv("results_v5_xgboost_ecfp/perf_fold1.csv", sep="\t", index=None)
perf_fold2.to_csv("results_v5_xgboost_ecfp/perf_fold2.csv", sep="\t", index=None)
perf_fold3.to_csv("results_v5_xgboost_ecfp/perf_fold3.csv", sep="\t", index=None)

# %%
# hp selection based on AUC
print("           fold1           fold2           fold3")
print("AUC      =({:.4f}+/-{:.4f},{:.4f}+/-{:.4f},{:.4f}+/-{:.4f})".format(perf_fold1['auc'].mean(),
                                                                           perf_fold1['auc'].std(),
                                                                           perf_fold2['auc'].mean(),
                                                                           perf_fold2['auc'].std(),
                                                                           perf_fold3['auc'].mean(),
                                                                           perf_fold3['auc'].std()))

print("PRECISION=({:.4f}+/-{:.4f},{:.4f}+/-{:.4f},{:.4f}+/-{:.4f})".format(perf_fold1['precision'].mean(),
                                                                           perf_fold1['precision'].std(),
                                                                           perf_fold2['precision'].mean(),
                                                                           perf_fold2['precision'].std(),
                                                                           perf_fold3['precision'].mean(),
                                                                           perf_fold3['precision'].std()))

print("RECALL   =({:.4f}+/-{:.4f},{:.4f}+/-{:.4f},{:.4f}+/-{:.4f})".format(perf_fold1['recall'].mean(),
                                                                           perf_fold1['recall'].std(),
                                                                           perf_fold2['recall'].mean(),
                                                                           perf_fold2['recall'].std(),
                                                                           perf_fold3['recall'].mean(),
                                                                           perf_fold3['recall'].std()))

print("KAPPA    =({:.4f}+/-{:.4f},{:.4f}+/-{:.4f},{:.4f}+/-{:.4f})".format(perf_fold1['kappa'].mean(),
                                                                           perf_fold1['kappa'].std(),
                                                                           perf_fold2['kappa'].mean(),
                                                                           perf_fold2['kappa'].std(),
                                                                           perf_fold3['kappa'].mean(),
                                                                           perf_fold3['kappa'].std()))
# Out:
#            fold1           fold2           fold3
# AUC      =(0.8084+/-0.1212,0.8067+/-0.1224,0.8106+/-0.1177)
# PRECISION=(0.6579+/-0.2562,0.6549+/-0.2602,0.6677+/-0.2410)
# RECALL   =(0.5599+/-0.3462,0.5524+/-0.3426,0.5577+/-0.3394)
# KAPPA    =(0.3626+/-0.2411,0.3619+/-0.2339,0.3649+/-0.2359)

# %% [markdown]
# ## find out best HP out of three outer folds

# %%
# get the best HP out of the three HP selected in inner loop based on outer loop performances
best_hp_for_full_scale = []
for i in range(526):
    
    best_fold = np.argmax(np.array([perf_fold1.iloc[i]['auc'],
                                    perf_fold2.iloc[i]['auc'],
                                    perf_fold3.iloc[i]['auc']]))
    
    
    best_hp = np.array([perf_fold1.iloc[i]['hp'],
                        perf_fold2.iloc[i]['hp'],
                        perf_fold3.iloc[i]['hp']])[best_fold]
    
    
    best_hp_for_full_scale.append(best_hp)

# %%
# select one best HP per target based on full outer loop perf
#

# %%
best_hp_for_full_scale = xgb_outer.sort_values('auc',ascending=False).groupby(['target']).first().reset_index()['hp'].values

# %%
# generate commands for full-scale models to run 
#
# Usage: python xgboost_model.py [target_idx] [obj] [lr] [scale_pos_w] [n_Estim] [max_depth]
srun_cmd = 'srun --partition=core -c 12 --time=3-00:00:00 -J xgb'

for i in range(526):
    target  = i
    hp      = best_hp_for_full_scale[i].split('-')
    booster = hp[0].replace('booster_', '')
    lr      = hp[1].replace('learning_rate_', '')
    max_d   = hp[2].replace('max_depth_', '')
    n_estim = hp[3].replace('n_estimators_', '')
    obj     = hp[4].replace('objective_', '')
    scale_pw= hp[5].replace('scale_pos_weight_', '')
    print("{}{} python xgboost_model.py {} {} {} {} {} {} & ".format(srun_cmd, i, target, obj, lr, scale_pw, n_estim, max_d))
# Out:
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb0 python xgboost_model.py 0 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb1 python xgboost_model.py 1 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb2 python xgboost_model.py 2 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb3 python xgboost_model.py 3 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb4 python xgboost_model.py 4 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb5 python xgboost_model.py 5 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb6 python xgboost_model.py 6 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb7 python xgboost_model.py 7 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb8 python xgboost_model.py 8 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb9 python xgboost_model.py 9 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb10 python xgboost_model.py 10 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb11 python xgboost_model.py 11 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb12 python xgboost_model.py 12 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb13 python xgboost_model.py 13 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb14 python xgboost_model.py 14 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb15 python xgboost_model.py 15 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb16 python xgboost_model.py 16 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb17 python xgboost_model.py 17 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb18 python xgboost_model.py 18 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb19 python xgboost_model.py 19 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb20 python xgboost_model.py 20 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb21 python xgboost_model.py 21 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb22 python xgboost_model.py 22 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb23 python xgboost_model.py 23 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb24 python xgboost_model.py 24 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb25 python xgboost_model.py 25 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb26 python xgboost_model.py 26 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb27 python xgboost_model.py 27 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb28 python xgboost_model.py 28 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb29 python xgboost_model.py 29 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb30 python xgboost_model.py 30 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb31 python xgboost_model.py 31 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb32 python xgboost_model.py 32 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb33 python xgboost_model.py 33 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb34 python xgboost_model.py 34 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb35 python xgboost_model.py 35 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb36 python xgboost_model.py 36 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb37 python xgboost_model.py 37 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb38 python xgboost_model.py 38 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb39 python xgboost_model.py 39 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb40 python xgboost_model.py 40 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb41 python xgboost_model.py 41 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb42 python xgboost_model.py 42 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb43 python xgboost_model.py 43 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb44 python xgboost_model.py 44 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb45 python xgboost_model.py 45 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb46 python xgboost_model.py 46 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb47 python xgboost_model.py 47 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb48 python xgboost_model.py 48 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb49 python xgboost_model.py 49 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb50 python xgboost_model.py 50 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb51 python xgboost_model.py 51 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb52 python xgboost_model.py 52 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb53 python xgboost_model.py 53 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb54 python xgboost_model.py 54 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb55 python xgboost_model.py 55 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb56 python xgboost_model.py 56 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb57 python xgboost_model.py 57 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb58 python xgboost_model.py 58 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb59 python xgboost_model.py 59 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb60 python xgboost_model.py 60 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb61 python xgboost_model.py 61 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb62 python xgboost_model.py 62 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb63 python xgboost_model.py 63 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb64 python xgboost_model.py 64 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb65 python xgboost_model.py 65 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb66 python xgboost_model.py 66 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb67 python xgboost_model.py 67 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb68 python xgboost_model.py 68 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb69 python xgboost_model.py 69 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb70 python xgboost_model.py 70 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb71 python xgboost_model.py 71 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb72 python xgboost_model.py 72 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb73 python xgboost_model.py 73 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb74 python xgboost_model.py 74 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb75 python xgboost_model.py 75 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb76 python xgboost_model.py 76 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb77 python xgboost_model.py 77 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb78 python xgboost_model.py 78 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb79 python xgboost_model.py 79 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb80 python xgboost_model.py 80 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb81 python xgboost_model.py 81 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb82 python xgboost_model.py 82 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb83 python xgboost_model.py 83 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb84 python xgboost_model.py 84 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb85 python xgboost_model.py 85 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb86 python xgboost_model.py 86 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb87 python xgboost_model.py 87 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb88 python xgboost_model.py 88 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb89 python xgboost_model.py 89 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb90 python xgboost_model.py 90 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb91 python xgboost_model.py 91 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb92 python xgboost_model.py 92 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb93 python xgboost_model.py 93 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb94 python xgboost_model.py 94 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb95 python xgboost_model.py 95 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb96 python xgboost_model.py 96 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb97 python xgboost_model.py 97 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb98 python xgboost_model.py 98 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb99 python xgboost_model.py 99 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb100 python xgboost_model.py 100 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb101 python xgboost_model.py 101 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb102 python xgboost_model.py 102 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb103 python xgboost_model.py 103 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb104 python xgboost_model.py 104 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb105 python xgboost_model.py 105 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb106 python xgboost_model.py 106 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb107 python xgboost_model.py 107 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb108 python xgboost_model.py 108 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb109 python xgboost_model.py 109 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb110 python xgboost_model.py 110 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb111 python xgboost_model.py 111 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb112 python xgboost_model.py 112 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb113 python xgboost_model.py 113 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb114 python xgboost_model.py 114 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb115 python xgboost_model.py 115 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb116 python xgboost_model.py 116 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb117 python xgboost_model.py 117 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb118 python xgboost_model.py 118 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb119 python xgboost_model.py 119 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb120 python xgboost_model.py 120 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb121 python xgboost_model.py 121 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb122 python xgboost_model.py 122 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb123 python xgboost_model.py 123 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb124 python xgboost_model.py 124 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb125 python xgboost_model.py 125 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb126 python xgboost_model.py 126 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb127 python xgboost_model.py 127 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb128 python xgboost_model.py 128 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb129 python xgboost_model.py 129 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb130 python xgboost_model.py 130 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb131 python xgboost_model.py 131 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb132 python xgboost_model.py 132 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb133 python xgboost_model.py 133 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb134 python xgboost_model.py 134 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb135 python xgboost_model.py 135 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb136 python xgboost_model.py 136 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb137 python xgboost_model.py 137 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb138 python xgboost_model.py 138 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb139 python xgboost_model.py 139 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb140 python xgboost_model.py 140 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb141 python xgboost_model.py 141 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb142 python xgboost_model.py 142 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb143 python xgboost_model.py 143 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb144 python xgboost_model.py 144 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb145 python xgboost_model.py 145 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb146 python xgboost_model.py 146 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb147 python xgboost_model.py 147 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb148 python xgboost_model.py 148 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb149 python xgboost_model.py 149 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb150 python xgboost_model.py 150 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb151 python xgboost_model.py 151 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb152 python xgboost_model.py 152 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb153 python xgboost_model.py 153 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb154 python xgboost_model.py 154 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb155 python xgboost_model.py 155 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb156 python xgboost_model.py 156 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb157 python xgboost_model.py 157 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb158 python xgboost_model.py 158 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb159 python xgboost_model.py 159 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb160 python xgboost_model.py 160 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb161 python xgboost_model.py 161 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb162 python xgboost_model.py 162 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb163 python xgboost_model.py 163 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb164 python xgboost_model.py 164 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb165 python xgboost_model.py 165 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb166 python xgboost_model.py 166 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb167 python xgboost_model.py 167 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb168 python xgboost_model.py 168 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb169 python xgboost_model.py 169 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb170 python xgboost_model.py 170 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb171 python xgboost_model.py 171 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb172 python xgboost_model.py 172 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb173 python xgboost_model.py 173 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb174 python xgboost_model.py 174 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb175 python xgboost_model.py 175 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb176 python xgboost_model.py 176 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb177 python xgboost_model.py 177 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb178 python xgboost_model.py 178 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb179 python xgboost_model.py 179 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb180 python xgboost_model.py 180 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb181 python xgboost_model.py 181 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb182 python xgboost_model.py 182 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb183 python xgboost_model.py 183 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb184 python xgboost_model.py 184 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb185 python xgboost_model.py 185 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb186 python xgboost_model.py 186 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb187 python xgboost_model.py 187 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb188 python xgboost_model.py 188 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb189 python xgboost_model.py 189 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb190 python xgboost_model.py 190 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb191 python xgboost_model.py 191 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb192 python xgboost_model.py 192 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb193 python xgboost_model.py 193 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb194 python xgboost_model.py 194 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb195 python xgboost_model.py 195 binary:logistic 0.05 10 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb196 python xgboost_model.py 196 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb197 python xgboost_model.py 197 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb198 python xgboost_model.py 198 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb199 python xgboost_model.py 199 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb200 python xgboost_model.py 200 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb201 python xgboost_model.py 201 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb202 python xgboost_model.py 202 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb203 python xgboost_model.py 203 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb204 python xgboost_model.py 204 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb205 python xgboost_model.py 205 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb206 python xgboost_model.py 206 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb207 python xgboost_model.py 207 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb208 python xgboost_model.py 208 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb209 python xgboost_model.py 209 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb210 python xgboost_model.py 210 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb211 python xgboost_model.py 211 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb212 python xgboost_model.py 212 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb213 python xgboost_model.py 213 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb214 python xgboost_model.py 214 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb215 python xgboost_model.py 215 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb216 python xgboost_model.py 216 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb217 python xgboost_model.py 217 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb218 python xgboost_model.py 218 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb219 python xgboost_model.py 219 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb220 python xgboost_model.py 220 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb221 python xgboost_model.py 221 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb222 python xgboost_model.py 222 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb223 python xgboost_model.py 223 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb224 python xgboost_model.py 224 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb225 python xgboost_model.py 225 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb226 python xgboost_model.py 226 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb227 python xgboost_model.py 227 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb228 python xgboost_model.py 228 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb229 python xgboost_model.py 229 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb230 python xgboost_model.py 230 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb231 python xgboost_model.py 231 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb232 python xgboost_model.py 232 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb233 python xgboost_model.py 233 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb234 python xgboost_model.py 234 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb235 python xgboost_model.py 235 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb236 python xgboost_model.py 236 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb237 python xgboost_model.py 237 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb238 python xgboost_model.py 238 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb239 python xgboost_model.py 239 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb240 python xgboost_model.py 240 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb241 python xgboost_model.py 241 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb242 python xgboost_model.py 242 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb243 python xgboost_model.py 243 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb244 python xgboost_model.py 244 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb245 python xgboost_model.py 245 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb246 python xgboost_model.py 246 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb247 python xgboost_model.py 247 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb248 python xgboost_model.py 248 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb249 python xgboost_model.py 249 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb250 python xgboost_model.py 250 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb251 python xgboost_model.py 251 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb252 python xgboost_model.py 252 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb253 python xgboost_model.py 253 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb254 python xgboost_model.py 254 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb255 python xgboost_model.py 255 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb256 python xgboost_model.py 256 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb257 python xgboost_model.py 257 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb258 python xgboost_model.py 258 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb259 python xgboost_model.py 259 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb260 python xgboost_model.py 260 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb261 python xgboost_model.py 261 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb262 python xgboost_model.py 262 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb263 python xgboost_model.py 263 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb264 python xgboost_model.py 264 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb265 python xgboost_model.py 265 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb266 python xgboost_model.py 266 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb267 python xgboost_model.py 267 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb268 python xgboost_model.py 268 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb269 python xgboost_model.py 269 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb270 python xgboost_model.py 270 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb271 python xgboost_model.py 271 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb272 python xgboost_model.py 272 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb273 python xgboost_model.py 273 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb274 python xgboost_model.py 274 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb275 python xgboost_model.py 275 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb276 python xgboost_model.py 276 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb277 python xgboost_model.py 277 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb278 python xgboost_model.py 278 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb279 python xgboost_model.py 279 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb280 python xgboost_model.py 280 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb281 python xgboost_model.py 281 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb282 python xgboost_model.py 282 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb283 python xgboost_model.py 283 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb284 python xgboost_model.py 284 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb285 python xgboost_model.py 285 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb286 python xgboost_model.py 286 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb287 python xgboost_model.py 287 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb288 python xgboost_model.py 288 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb289 python xgboost_model.py 289 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb290 python xgboost_model.py 290 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb291 python xgboost_model.py 291 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb292 python xgboost_model.py 292 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb293 python xgboost_model.py 293 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb294 python xgboost_model.py 294 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb295 python xgboost_model.py 295 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb296 python xgboost_model.py 296 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb297 python xgboost_model.py 297 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb298 python xgboost_model.py 298 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb299 python xgboost_model.py 299 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb300 python xgboost_model.py 300 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb301 python xgboost_model.py 301 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb302 python xgboost_model.py 302 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb303 python xgboost_model.py 303 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb304 python xgboost_model.py 304 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb305 python xgboost_model.py 305 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb306 python xgboost_model.py 306 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb307 python xgboost_model.py 307 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb308 python xgboost_model.py 308 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb309 python xgboost_model.py 309 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb310 python xgboost_model.py 310 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb311 python xgboost_model.py 311 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb312 python xgboost_model.py 312 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb313 python xgboost_model.py 313 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb314 python xgboost_model.py 314 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb315 python xgboost_model.py 315 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb316 python xgboost_model.py 316 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb317 python xgboost_model.py 317 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb318 python xgboost_model.py 318 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb319 python xgboost_model.py 319 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb320 python xgboost_model.py 320 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb321 python xgboost_model.py 321 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb322 python xgboost_model.py 322 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb323 python xgboost_model.py 323 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb324 python xgboost_model.py 324 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb325 python xgboost_model.py 325 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb326 python xgboost_model.py 326 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb327 python xgboost_model.py 327 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb328 python xgboost_model.py 328 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb329 python xgboost_model.py 329 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb330 python xgboost_model.py 330 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb331 python xgboost_model.py 331 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb332 python xgboost_model.py 332 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb333 python xgboost_model.py 333 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb334 python xgboost_model.py 334 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb335 python xgboost_model.py 335 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb336 python xgboost_model.py 336 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb337 python xgboost_model.py 337 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb338 python xgboost_model.py 338 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb339 python xgboost_model.py 339 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb340 python xgboost_model.py 340 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb341 python xgboost_model.py 341 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb342 python xgboost_model.py 342 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb343 python xgboost_model.py 343 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb344 python xgboost_model.py 344 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb345 python xgboost_model.py 345 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb346 python xgboost_model.py 346 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb347 python xgboost_model.py 347 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb348 python xgboost_model.py 348 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb349 python xgboost_model.py 349 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb350 python xgboost_model.py 350 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb351 python xgboost_model.py 351 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb352 python xgboost_model.py 352 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb353 python xgboost_model.py 353 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb354 python xgboost_model.py 354 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb355 python xgboost_model.py 355 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb356 python xgboost_model.py 356 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb357 python xgboost_model.py 357 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb358 python xgboost_model.py 358 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb359 python xgboost_model.py 359 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb360 python xgboost_model.py 360 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb361 python xgboost_model.py 361 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb362 python xgboost_model.py 362 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb363 python xgboost_model.py 363 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb364 python xgboost_model.py 364 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb365 python xgboost_model.py 365 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb366 python xgboost_model.py 366 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb367 python xgboost_model.py 367 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb368 python xgboost_model.py 368 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb369 python xgboost_model.py 369 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb370 python xgboost_model.py 370 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb371 python xgboost_model.py 371 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb372 python xgboost_model.py 372 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb373 python xgboost_model.py 373 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb374 python xgboost_model.py 374 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb375 python xgboost_model.py 375 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb376 python xgboost_model.py 376 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb377 python xgboost_model.py 377 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb378 python xgboost_model.py 378 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb379 python xgboost_model.py 379 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb380 python xgboost_model.py 380 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb381 python xgboost_model.py 381 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb382 python xgboost_model.py 382 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb383 python xgboost_model.py 383 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb384 python xgboost_model.py 384 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb385 python xgboost_model.py 385 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb386 python xgboost_model.py 386 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb387 python xgboost_model.py 387 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb388 python xgboost_model.py 388 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb389 python xgboost_model.py 389 binary:logistic 0.05 10 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb390 python xgboost_model.py 390 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb391 python xgboost_model.py 391 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb392 python xgboost_model.py 392 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb393 python xgboost_model.py 393 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb394 python xgboost_model.py 394 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb395 python xgboost_model.py 395 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb396 python xgboost_model.py 396 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb397 python xgboost_model.py 397 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb398 python xgboost_model.py 398 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb399 python xgboost_model.py 399 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb400 python xgboost_model.py 400 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb401 python xgboost_model.py 401 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb402 python xgboost_model.py 402 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb403 python xgboost_model.py 403 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb404 python xgboost_model.py 404 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb405 python xgboost_model.py 405 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb406 python xgboost_model.py 406 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb407 python xgboost_model.py 407 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb408 python xgboost_model.py 408 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb409 python xgboost_model.py 409 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb410 python xgboost_model.py 410 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb411 python xgboost_model.py 411 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb412 python xgboost_model.py 412 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb413 python xgboost_model.py 413 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb414 python xgboost_model.py 414 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb415 python xgboost_model.py 415 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb416 python xgboost_model.py 416 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb417 python xgboost_model.py 417 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb418 python xgboost_model.py 418 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb419 python xgboost_model.py 419 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb420 python xgboost_model.py 420 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb421 python xgboost_model.py 421 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb422 python xgboost_model.py 422 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb423 python xgboost_model.py 423 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb424 python xgboost_model.py 424 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb425 python xgboost_model.py 425 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb426 python xgboost_model.py 426 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb427 python xgboost_model.py 427 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb428 python xgboost_model.py 428 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb429 python xgboost_model.py 429 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb430 python xgboost_model.py 430 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb431 python xgboost_model.py 431 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb432 python xgboost_model.py 432 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb433 python xgboost_model.py 433 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb434 python xgboost_model.py 434 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb435 python xgboost_model.py 435 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb436 python xgboost_model.py 436 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb437 python xgboost_model.py 437 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb438 python xgboost_model.py 438 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb439 python xgboost_model.py 439 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb440 python xgboost_model.py 440 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb441 python xgboost_model.py 441 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb442 python xgboost_model.py 442 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb443 python xgboost_model.py 443 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb444 python xgboost_model.py 444 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb445 python xgboost_model.py 445 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb446 python xgboost_model.py 446 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb447 python xgboost_model.py 447 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb448 python xgboost_model.py 448 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb449 python xgboost_model.py 449 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb450 python xgboost_model.py 450 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb451 python xgboost_model.py 451 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb452 python xgboost_model.py 452 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb453 python xgboost_model.py 453 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb454 python xgboost_model.py 454 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb455 python xgboost_model.py 455 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb456 python xgboost_model.py 456 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb457 python xgboost_model.py 457 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb458 python xgboost_model.py 458 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb459 python xgboost_model.py 459 binary:logistic 0.05 10 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb460 python xgboost_model.py 460 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb461 python xgboost_model.py 461 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb462 python xgboost_model.py 462 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb463 python xgboost_model.py 463 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb464 python xgboost_model.py 464 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb465 python xgboost_model.py 465 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb466 python xgboost_model.py 466 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb467 python xgboost_model.py 467 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb468 python xgboost_model.py 468 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb469 python xgboost_model.py 469 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb470 python xgboost_model.py 470 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb471 python xgboost_model.py 471 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb472 python xgboost_model.py 472 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb473 python xgboost_model.py 473 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb474 python xgboost_model.py 474 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb475 python xgboost_model.py 475 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb476 python xgboost_model.py 476 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb477 python xgboost_model.py 477 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb478 python xgboost_model.py 478 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb479 python xgboost_model.py 479 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb480 python xgboost_model.py 480 binary:logistic 0.05 10 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb481 python xgboost_model.py 481 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb482 python xgboost_model.py 482 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb483 python xgboost_model.py 483 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb484 python xgboost_model.py 484 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb485 python xgboost_model.py 485 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb486 python xgboost_model.py 486 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb487 python xgboost_model.py 487 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb488 python xgboost_model.py 488 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb489 python xgboost_model.py 489 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb490 python xgboost_model.py 490 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb491 python xgboost_model.py 491 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb492 python xgboost_model.py 492 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb493 python xgboost_model.py 493 binary:logistic 0.05 1 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb494 python xgboost_model.py 494 binary:logistic 0.05 5 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb495 python xgboost_model.py 495 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb496 python xgboost_model.py 496 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb497 python xgboost_model.py 497 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb498 python xgboost_model.py 498 binary:logistic 0.05 5 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb499 python xgboost_model.py 499 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb500 python xgboost_model.py 500 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb501 python xgboost_model.py 501 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb502 python xgboost_model.py 502 binary:logistic 0.05 10 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb503 python xgboost_model.py 503 binary:logistic 0.05 1 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb504 python xgboost_model.py 504 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb505 python xgboost_model.py 505 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb506 python xgboost_model.py 506 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb507 python xgboost_model.py 507 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb508 python xgboost_model.py 508 binary:logistic 0.05 5 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb509 python xgboost_model.py 509 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb510 python xgboost_model.py 510 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb511 python xgboost_model.py 511 binary:logistic 0.05 1 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb512 python xgboost_model.py 512 binary:logistic 0.05 10 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb513 python xgboost_model.py 513 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb514 python xgboost_model.py 514 binary:logistic 0.05 10 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb515 python xgboost_model.py 515 binary:logistic 0.05 1 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb516 python xgboost_model.py 516 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb517 python xgboost_model.py 517 binary:logistic 0.05 5 200 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb518 python xgboost_model.py 518 binary:logistic 0.05 5 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb519 python xgboost_model.py 519 binary:logistic 0.05 1 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb520 python xgboost_model.py 520 binary:logistic 0.05 10 50 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb521 python xgboost_model.py 521 binary:logistic 0.05 10 50 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb522 python xgboost_model.py 522 binary:logistic 0.05 1 100 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb523 python xgboost_model.py 523 binary:logistic 0.05 5 200 10 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb524 python xgboost_model.py 524 binary:logistic 0.05 10 100 5 &
# srun --partition=core -c 12 --time=3-00:00:00 -J xgb525 python xgboost_model.py 525 binary:logistic 0.05 10 200 5 &
